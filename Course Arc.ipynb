# %% [markdown]
# # Course Arc
#
# ## Class 1
# * Course introduction and overview
# * Data immersion in the world of open source tools, such as R and Python, and APIs to connect to a world of data.
#     * The scatterplot and the histogram
#     * A line as feature reduction and explanation
#
# ## Class 2
# * The algorithm
#     * Representation
#     * Optimization
#     * Evaluation
# * The theoretical mininimum of probability and statistics using Gelnter *et al.* Exhibits 9-1 and 9-2 to motivate all ideas
#     * Probability distribution as an abstraction
#         * The normal distribution as an abstraction of asset returns: Exhibit 9-1
#     * Measures of central tendancy as feature reduction
#         * Expected returns (a mean) and risk (a standard deviation): Exhibit 9-2
# * Making the machines do the work
#
# ## Class 3
# * The framework of hypothesis testing using a null hypothesis, H$_0$
# * Classical (or frequentist) hypothesis testing using the normal distribution
#     * The Central Limit Theorem proved graphically
#     * Two possible errors
#         * Type I: Reject H$_0$ when it is true
#         * Type II: Fail to reject H$_0$ when it is false (or when H$_1$ is true)
#     * Your choice regarding the determination of P(Type I error).
#         * Frequently 5% or 0.05 $\rightarrow \pm 1.96$ critical value or 2$\sigma$
#         * Weak standard in social sciences, such as economics and finance.
#         * More stringent standard is 1% or 0.01 $\rightarrow \pm 2.54$ critical value or  3$\sigma$
# * The Capital Asset Pricing Models (CAPM)
#     * Unification of finance theory, classical hypothesis testing, and the algorithm (linear regression)
#
# ## Class 4
# * More examples of classical hypothesis testing using the bivariate algorithm.
# * A discussion of empirical causation: **Raise rents to lower vacancy!**
# * Judea Pearl's ladder of causation.
#     * [Savage and Vo](https://github.com/thsavage/Causation/blob/master/Poster.pdf): An example of the algorithmic counterfactual.
#
# ## Classes 5 and 6
# * Extension to multivariate algorithm.
#     * Extension is trivial, and interpretation (including classical hypothesis testing) remains.
#     * Multivariate regression remains a staple of analytics because of ease of interpretation and tractibility.
# * The R$^2$ metric is often misused, in particular when it is cited in isolation as a measure of the predictive power of an algorithmic specification.
#     * The metric is relative and to be used when comparing nested specifications.
#     * CAPM is nested in FF3F, which is nested in FF5F.  One can compare the R$^2$ across the models.
#     * Certain use cases are very difficult, such as interest rate prediction.  One can find a relationship between short- and long-term interest rates that still has little predictive power.
#
# * Some relevant math on calculating returns:
#
# $r_{t+1}= \displaystyle {\frac{p_{t+1}+d_t-p_t}{p_t}=\frac{p_{t+1}-p_t}{p_t}+\frac{d_t}{p_t}=\text{gain + yield}}$
#
# * Alternatively,
#
# $1+r_{t+1}= \displaystyle {\frac{p_{t+1}}{p_t}+\frac{d_t}{p_t}}$
#
# * If $d_t=0$ because we are calculating daily returns,
#
# $\ln(1+r_{t+1})= \displaystyle {\ln(p_{t+1})-\ln({p_t})}$
#
# * Because $\ln(1+r) \approx r \text{ for small } r$
#
# $r_{t+1} \approx \displaystyle {\ln(p_{t+1})-\ln({p_t})}$, which justifies the use of log returns for daily stock prices.
#
# * EMH:
#
# $E_t(p_{t+1})=p_t+\epsilon_{t+1}$ or $E_t(p_{t+1})-p_t=\epsilon_{t+1}$
#
# * Law of Iterated Expectations:
#
# $E_t\big(p_{t+1}-p_t \big| p_t\big)=E_t\big(\epsilon_{t+1} \big| p_t\big)$
#
# * The left side is expected returns, given today's knowledge, $p_t$, and the right side is the expectation of tomorrow's news given today's knowledge, $p_t$.  Tomorrow's news is not forecastable (otherwise it would be included in today's price).  Hence, expected returns cannot be forecasted.
#
# * Consider the market's recent reaction to the corona virus.
#
# ## Class 7
# * Midterm
#
#
# ## Class 8
# ### More on Omitted Variable Bias: Breaking Every Algorithm
# ### An Introduction to Machine Learning, Classification and Unsupervised Learning
#
# * Omitted variable bias: What cannot be measured, cannot be included in the fitting of any algorithm.
#     * As a result, we may have to rely on "proxies".
#     * It can be difficult to assess the actual impact.  In the Monte Carlo example, the positive correlation passed 1:1 on the measured impact.  That is, it biased upward our measurement.
#     * In the CBRE cap rate model, it induced a theoretically-incorrect impact on the relationship between long-term US Treasurys and cap rates.
#     * In the Griliches example, it biased upward the ROI to education.
#
# * On an introduction to machine learning, the use case changed.
#     * Machine learning is typically focused on prediction (the Zestimate for example) rather than evaluating the impact of an intervention (such as the ROI to education).
#      Key insight was not to use all of the data available, but rather randomly "split" the data into two types: training data and test data.  The algorithm is fitted on the training data, but its performance is evaluated on the test data.  We will explore this idea in-depth in our next class.

# %% [markdown]
# ## Class 9
#
# * See Jupyter Notebook for notes.
# * See R Notebook for implimentation.
# * Consider LeCun's MNIST data of handwritten digits.
#     * Effort driven by the desire to teach machines how to read hand-written digits for the U.S. Postal Service.
#     * Created a revolution in the use of digitization for image and voice recognition.
#     * The goal is reduce the dimension of the problem: one image has many pixels, and we have many images.
# * Two popular clustering techniques: PCA and TSNE (t-student stochastic neighbor embedded algorthm).
# * See the images below for the use of PCA and TSNE for clustering.
#     * Note that PCA is an old algorithm that does fairly well clustering the digits (with the two principle components with the largest Eigenvectors or factors that have explanatory).
#     * TSNE does much better, but requires more computational power.

# %%
from IPython.display import Image

# %%
url = 'http://www.undergroundwineletter.com/wp-content/uploads/2012/01/birds-of-a-feather-cartoon.png'
Image(url, width=700, height=700)

# %%
url = '/Users/timothysavage/Desktop/Schack Spring Real Estate Data Science/PCA with MNIST.jpeg'
Image(url, width=700, height=700)

# %%
url = '/Users/timothysavage/Desktop/Schack Spring Real Estate Data Science/TSNE with MNIST.jpeg'
Image(url, width=700, height=700)

# %% [markdown]
# ## Class 10

# %%
url = '/Users/timothysavage/Desktop/Schack Spring Real Estate Data Science/cannon.jpg'
Image(url, width=200, height=200)

# %% [markdown]
# * First class of a three-class arc in time series analysis.
#     * See R Notebook.
#
#
# * Indepensible tool of CRE data analytics.
#
#
# * The image above is a picture of the cannonical textbook for frequenist time series: an indespensible complilation of all thing related to time series.
#     * There are Bayesian representations of many algorithms we will study.
#     * The hidden Markov model is quasi-Bayesian.
#
#
# * Markov's logic using the Markov chain was a critical development in mathematical statisics.
#     * Prior to Markov's representation, arguments focused on independent trials, in which the past played no role on the present.  Leplace's proof of the Central Limit Theorem relied on the idea of independent trials (although Leplace was also developing the Law of Inverse Probability at the time).
#     * Markov demostrated one could integrate path- or state-dependency and find, like the CLT, stable limiting distributions.
#     * These distributions independent of the initial state of the system.
#     * Markov provided another critical insight: statements about the future are inherently probabilistic.
#     * He also provided a critical tool in simulation: Markov chain Monte Carlo.
#     * The idea of the absorbing state was developed later to explore the idea of degenerate distributions.

# %% [markdown]
# ## Class 11
#
# * Large-scale macroeconometric models (a combination of macroeconomics and applied statistics) were used until the late 1970's for the purpose of policy simulation.
#     * As discussed earlier, these models did not perform well in the face of *stagflation*, a combination of low economic growth and high inflation.
#     * Economists, such as NYU's *Tom Sargent*, began to focus on an alternative: if the goal is forecasting, using *parsimonious* approaches is preferred.  They incorporated ideas from Markov, as well as traditional ideas around independent experiements, called "white noise".
#     * Thus, the autoregressive model was created.
#
#
#
# * $y_t = \rho y_{t-1} + \epsilon_t$ is the AR(1) model.
#     * $\rho y_{t-1}$ is the Markov component, while $\epsilon_t$ is the white noise component.
#     * As long as $|\rho| \lt 1$, the AR(1) model can capture a rich combination of:
#         * Trends and serial depedence, while remaining **stationary**.
#     * As $|\rho| \rightarrow 1$, the Markov component dominates, and the process becomes unstationary.
#         * Recall that $\displaystyle {Var(y_t) = Var\left(\sum_{j=1}^\infty \rho^{j-1} \epsilon_{t-j+1}\right) = \sum_{j=1}^\infty \rho^{2(j-1)} Var(\epsilon_{t-j+1}) = \sum_{j=1}^\infty \rho^{2(j-1)} = \frac{1}{1-\rho^2}}$
#         * Recall that $y_t = y_{t-1} + \epsilon_t$ is a Markov chain or random walk.  This process is called *integrated of order one* or I(1).  It is not stationary.  In contrast, $y_t - y_{t-1} = \epsilon_t$ is stable.
#     * Usefully, Corr$(y_t, y_{t-k}) = \rho^k$, which is geometric decay.  Hence, Corr$(y_t, y_{t}) = \rho^0 = 1$, while Corr$(y_t, y_{t-1}) = \rho$.
#     * See the Jupyter notes for mathematics and visual proofs.
#
#
#
# * The AR(1) representation is an example of the linear algorithm, and I showed this when I presented the *perfect model*.
#     * We tend not to fit the linear model or to create tables of frequentist regression results.
#     * Instead we show graphs of the *Autocorrelation Function* or ACF, which allows us to see the results.
#     * We deployed the ACF and its frequentist 95% confidence interval, which allows us to address hypothesis testing.
#         * Equity prices are integrated of order 1: $E_t p_{t+1} = p_t + \epsilon_{t+1}$, and $\epsilon_{t+1}$ is unforecastable news.
#         * No evidence that returns, $r_t = log(p_t) - log(p_{t-1})$, are autocorrelated.
#         * Volatility, $\sigma(r_t)$, is autocorrelated, but not exploitable.

# %% [markdown]
# ## Class 12
#
# * Synthesis of all components to create the ARIMA($p, d, q$)
# * Forecasting with ARIMAs
# * The Hidden Markov Model and evaluaing *regime change*

# %% [markdown]
# ## Class 13
#
# * An Introduction to Deep Learning and Bayesian Inference
#     * Two old ideas are reborn with computational power and digital data
#     * [Savage and Vo](https://github.com/thsavage/Deep-Learning-and-Finance/blob/master/Deep%20Learning%20and%20Finance%20Poster.pdf): Don't bring a battleship to the Head of the Charles
# * The Bayesian CAPM: Directly address interesting questions
#     * What is the Pr(ROI on education is substantial)?
# * What is AI?
